# %%
from tqdm import tqdm
import torch.nn as nn
import numpy as np
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# Fill in the code below to make Beam Search work.
FILL_IN = "FILL IN"

# %% [markdown]
# ### Get the data and process
# - This is the Mysterious island found in Project Gutenberg.

# %%
## Reading and processing text
with open('data/1268-0.txt', 'r', encoding="utf8") as fp:
    text=fp.read()
    
start_indx = text.find('THE MYSTERIOUS ISLAND')
end_indx = text.find('End of the Project Gutenberg')

text = text[start_indx:end_indx]
char_set = set(text)
print('Total Length:', len(text))
print('Unique Characters:', len(char_set))
assert(len(text) == 1130711)
assert(len(char_set) == 85)
# Out:
# Total Length: 1130711
# Unique Characters: 85

# %% [markdown]
# ### Tokenze and get other helpers
# - We do this manually since everything is character based.

# %%
# The universe of words.
chars_sorted = sorted(char_set)

# Effectively, these maps are the tokenizer.
char2int = {ch:i for i,ch in enumerate(chars_sorted)}
int2char = np.array(chars_sorted)

# Tokenize the entire corpus.
text_encoded = np.array(
    [char2int[ch] for ch in text],
    dtype=np.int32)

print('Text encoded shape: ', text_encoded.shape)

print(text[:15], '     == Encoding ==> ', text_encoded[:15])
print(text_encoded[15:21], ' == Reverse  ==> ', ''.join(int2char[text_encoded[15:21]]))
# Out:
# Text encoded shape:  (1130711,)
# THE MYSTERIOUS       == Encoding ==>  [48 36 33  1 41 53 47 48 33 46 37 43 49 47  1]
# [37 47 40 29 42 32]  == Reverse  ==>  ISLAND

# %% [markdown]
# ### Load the model

# %%
device = torch.device("cpu")

# %%
# !du -h hw7_model.pt
# Out:
# 7.1M	hw7_model.pt

# %%
# Lost a traced version of this model.
# Note this is the same as the HW 7 model but a little different
# The HW7 model had an if-else in its forward method, and this is not allowed.
# The forward method of this model takes hidden and cell, which could be all zeros but the user has to specify.
model = torch.jit.load('hw7_model.pt')

# %%
model
# Out:
# RecursiveScriptModule(
#   original_name=RNN
#   (embedding): RecursiveScriptModule(original_name=Embedding)
#   (rnn): RecursiveScriptModule(original_name=LSTM)
#   (fc): RecursiveScriptModule(original_name=Linear)
# )

# %%
# 'jit' does not save other methods on a model, we need to define this helper and use it below.
def init_hidden(model, batch_size):
    return (
        torch.zeros(1, batch_size, model.rnn_hidden_size),
        torch.zeros(1, batch_size, model.rnn_hidden_size)
    )

# %% [markdown]
# ### Beam search algorithm.
# - Good article: https://towardsdatascience.com/foundations-of-nlp-explained-visually-beam-search-how-it-works-1586b9849a24

# %%
def beam_search_decoding(
    model,
    starting_str, 
    len_generated_text=500, 
    beams=5,
    print_paths=True
):
    assert(len(starting_str) != 0)

    # Get the encoding of the starting_str as a tensor of ints.
    encoded_input = FILL_IN
    
    # Reshape the above to be of appropiate dimension.
    encoded_input = FILL_IN

    # Put the model in eval mode.
    FILL_IN
    
    # Unfortunately, jit save does not save methods other than forward.
    # Use init_hidden to get the first hidden and cell states.
    hidden, cell = FILL_IN
    
    hidden = hidden.to(device)
    
    cell = cell.to(device)
    
    generated_log_prob = 0
    generated_str = starting_str[0]
        
    # Build up the starting hidden and cell states.
    # You can do this all in one go?
    for i in range(len(starting_str)-1):
        # Feed each letter 1 by 1 and then get the final hidden state.
        # Get the character at index i and push it through the model.
        # Get the logits, the hidden and cell states, which would will need later.
        FILL_IN
        
        # Get the probability of the generated character.
        # For input of index i, we want the probability that the model generated i+1.
        # We push the startiing_str[i] into the model, and append starting_str[i+1] to generated_str.
        generated_str += FILL_IN
        
        # Get the probabilities of the different characters that the model this. 
        # You need to apply Softmax to the logits.
        probs = FILL_IN
        
        # Add the log probability of the  appened char (int) to the running generated log probability.
        generated_log_prob += FILL_IN
    
    # Get the last character in the encoded input.
    last_char_int = FILL_IN
    
    # Push this through the model.
    logits, (hidden, cell) = FILL_IN
    
    # As before, get the probaility per character.
    probs = FILL_IN
    
    new_beams = []
    
    for j, prob in enumerate(probs):
        # For each probability, append the tuple (hidden, cell, the generatd str with the jth index char, generated str's the log probablity)
        # Note this is the running generated str and generated log probability.
        new_beams.append(
            FILL_IN
        )
        
    # Sort the beams from most proable to least. Use -log(generated_prob).
    new_beams = FILL_IN
    
    beam_to_beam_data = {}
    
    # Add the top "beams" = 5 beams to the hash map.
    # We should have a map going {beam_id -> (hidden, cell, generated_str, geenrated_log_prob)}
    for beam in range(beams):
        beam_to_beam_data[beam] = FILL_IN
    
    print('The number of beams is', len(beam_to_beam_data))
    
    # For each index of generated text.
    for i in range(len_generated_text):
        # Define new beams.
        new_beams = []
        
        # For each beam.
        for beam in range(beams):
            
            # Grab the 4 elements associated with this beam from beam_to_beam_data.
            FILL_IN
            
            # Get the last char in the str that's in the beam.
            last_char_int = FILL_IN
            
            # Push hidden, cell and the last_char_int through the model.
            logits, (hidden, cell) = FILL_IN
            
            # Get the probabilities.
            probs = FILL_IN
            
            # As before, append the 4 elements associated with this new beam to new beams.
            for j, prob in enumerate(probs):
                new_beams.append(
                    FILL_IN
                )
        
        # Sort the beams from most probable to least. Use -log(p).
        new_beams = FILL_IN
                
        # The number of beams considered should always satisfy this.
        # Except for the first iteration.
        assert(len(new_beams) == beams * len(char2int))
        
        # Leave this to true.
        if print_paths:
            print("The first 5 paths beam paths and the associated data for them: ")
            for beam in range(5):
                generated_str, generated_log_prob = new_beams[beam][2:]
                print("Text: \"{}\" Prob {:0.30f}".format(
                        generated_str, np.exp(generated_log_prob)
                ))
            _ = input("Insert anything to continue ...")
            print("\n")
                
        # Update the beams to be equal to the top beams.
        for beam in range(beams):
            beam_to_beam_data[beam] = new_beams[beam]
            
    generated_strs = []
    generated_log_probs = []
    
    # Grab the top beams, and return them.
    for beam in range(beams):
        (_, _, generated_str, generated_log_prob) = beam_to_beam_data[beam]
        generated_strs.append(generated_str)
        generated_log_probs.append(generated_log_prob)        
                
    return generated_strs, [np.exp(_) for _ in generated_log_probs]

# %%
torch.manual_seed(1)
model.to('cpu')
beams=5
len_generated_text=500

generated_strs, generated_probs = beam_search_decoding(
    model,
    starting_str="The island",
    len_generated_text=len_generated_text,
    beams=beams
)

for beam in range(beams):
    print(f"Beam {beam} information: ")
    print(generated_strs[beam])
    print(generated_probs[beam])
# Out:
# The number of beams is 5
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, " Prob (beyond starting) 0.000520035624382387119506165885
# Text: "The island w" Prob (beyond starting) 0.000227799324636454402067883840
# Text: "The island?”" Prob (beyond starting) 0.000097528783550422128417051182
# Text: "The island o" Prob (beyond starting) 0.000093910921207016688472789256
# Text: "The island i" Prob (beyond starting) 0.000063718712271929359939465209
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island wa" Prob (beyond starting) 0.000172444312622175221702547354
# Text: "The island, w" Prob (beyond starting) 0.000092942431504603877394019018
# Text: "The island, a" Prob (beyond starting) 0.000090473014760760145456380821
# Text: "The island, t" Prob (beyond starting) 0.000070329177943556804835506524
# Text: "The island?”
# " Prob (beyond starting) 0.000062701887612621581271840632
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island was" Prob (beyond starting) 0.000168390777398385932048241465
# Text: "The island, an" Prob (beyond starting) 0.000071394498489104718345898970
# Text: "The island, th" Prob (beyond starting) 0.000063585879998671285631174632
# Text: "The island?”
#
# " Prob (beyond starting) 0.000062353845602206221278296372
# Text: "The island, wh" Prob (beyond starting) 0.000055470405798159414239179715
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island was " Prob (beyond starting) 0.000162886606720045377895075833
# Text: "The island, and" Prob (beyond starting) 0.000070901871302145183864618083
# Text: "The island?”
#
# “" Prob (beyond starting) 0.000043470926973089517287261729
# Text: "The island, the" Prob (beyond starting) 0.000041231253030852359447826216
# Text: "The island, who" Prob (beyond starting) 0.000031136489860345885078568573
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and " Prob (beyond starting) 0.000066633783205592716928147845
# Text: "The island, the " Prob (beyond starting) 0.000022295299832291799502258581
# Text: "The island was s" Prob (beyond starting) 0.000017944534091877657413669975
# Text: "The island, who " Prob (beyond starting) 0.000017057419277832911098284965
# Text: "The island was n" Prob (beyond starting) 0.000016321604081065519287890853
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and t" Prob (beyond starting) 0.000017958413385247575487502214
# Text: "The island was no" Prob (beyond starting) 0.000013530790669816228095206911
# Text: "The island was st" Prob (beyond starting) 0.000005924833556669433614597000
# Text: "The island, and w" Prob (beyond starting) 0.000005824252658846007486099713
# Text: "The island, and i" Prob (beyond starting) 0.000005722347216996238228770445
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and th" Prob (beyond starting) 0.000016443975701748143831764856
# Text: "The island was not" Prob (beyond starting) 0.000011276356243426131187963454
# Text: "The island, and it" Prob (beyond starting) 0.000004401433172553300938003359
# Text: "The island was sti" Prob (beyond starting) 0.000002779730699933294694564364
# Text: "The island, and wh" Prob (beyond starting) 0.000001813159164891349237427355
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and the" Prob (beyond starting) 0.000010454561324388920813739136
# Text: "The island was not " Prob (beyond starting) 0.000009205853143359940922918136
# Text: "The island, and it " Prob (beyond starting) 0.000004100519059773806692455363
# Text: "The island, and tha" Prob (beyond starting) 0.000003410578967898756639666197
# Text: "The island was stil" Prob (beyond starting) 0.000002749086953532576696961716
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and the " Prob (beyond starting) 0.000005812341588656687606283605
# Text: "The island, and that" Prob (beyond starting) 0.000003384754893271053863865010
# Text: "The island, and it w" Prob (beyond starting) 0.000003218232509092679415198908
# Text: "The island was still" Prob (beyond starting) 0.000002747602888444652123237479
# Text: "The island, and they" Prob (beyond starting) 0.000001530513553523463538271290
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and that " Prob (beyond starting) 0.000003094642141189091489450599
# Text: "The island was still " Prob (beyond starting) 0.000002619106736716375068125357
# Text: "The island, and it wa" Prob (beyond starting) 0.000002332773044231238275048653
# Text: "The island, and they " Prob (beyond starting) 0.000001463769443847624681070540
# Text: "The island, and the s" Prob (beyond starting) 0.000000840401564178404399010729
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was" Prob (beyond starting) 0.000002320178706958571389541322
# Text: "The island, and that t" Prob (beyond starting) 0.000001036602955026826357535076
# Text: "The island was still t" Prob (beyond starting) 0.000000548208028420043747882672
# Text: "The island, and that i" Prob (beyond starting) 0.000000465098739820374471948738
# Text: "The island, and they w" Prob (beyond starting) 0.000000397745411641401459637183
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was " Prob (beyond starting) 0.000002180166153715842196120136
# Text: "The island, and that th" Prob (beyond starting) 0.000000995319539659070688414517
# Text: "The island was still th" Prob (beyond starting) 0.000000319189288014528414445732
# Text: "The island, and that is" Prob (beyond starting) 0.000000311662237480900190940528
# Text: "The island, and they we" Prob (beyond starting) 0.000000187845091326499898787741
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and that the" Prob (beyond starting) 0.000000811750143478994685318972
# Text: "The island, and it was n" Prob (beyond starting) 0.000000460739898664555668927770
# Text: "The island, and it was t" Prob (beyond starting) 0.000000319451532426685134984253
# Text: "The island, and that is " Prob (beyond starting) 0.000000243904837724117802866432
# Text: "The island was still the" Prob (beyond starting) 0.000000200740499643505534539342
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and that the " Prob (beyond starting) 0.000000567758523085180477499388
# Text: "The island, and it was th" Prob (beyond starting) 0.000000259080082931205728881191
# Text: "The island, and it was no" Prob (beyond starting) 0.000000249608922243417446709549
# Text: "The island, and it was ne" Prob (beyond starting) 0.000000203408416592748565312351
# Text: "The island, and that is t" Prob (beyond starting) 0.000000162549003773046597461793
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was not" Prob (beyond starting) 0.000000223617078250826203708110
# Text: "The island, and it was the" Prob (beyond starting) 0.000000194868010696914758678606
# Text: "The island, and it was nec" Prob (beyond starting) 0.000000158633607752939597517313
# Text: "The island, and that is to" Prob (beyond starting) 0.000000140876502146442485525441
# Text: "The island, and that the s" Prob (beyond starting) 0.000000091168985280911766032845
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was not " Prob (beyond starting) 0.000000193269857724836685658546
# Text: "The island, and it was nece" Prob (beyond starting) 0.000000157542967282346663189670
# Text: "The island, and that is to " Prob (beyond starting) 0.000000127731702197862290253818
# Text: "The island, and it was the " Prob (beyond starting) 0.000000082838013607620644308573
# Text: "The island, and it was ther" Prob (beyond starting) 0.000000054961793308572583590739
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was neces" Prob (beyond starting) 0.000000156560949262643312743647
# Text: "The island, and it was there" Prob (beyond starting) 0.000000053867963854688683617974
# Text: "The island, and that is to s" Prob (beyond starting) 0.000000042620285320625669595069
# Text: "The island, and it was not a" Prob (beyond starting) 0.000000026380103147166685645907
# Text: "The island, and that is to b" Prob (beyond starting) 0.000000023313432578693227640123
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necess" Prob (beyond starting) 0.000000155033162885432141675219
# Text: "The island, and that is to sa" Prob (beyond starting) 0.000000036562188382879102302289
# Text: "The island, and that is to be" Prob (beyond starting) 0.000000020992617679836261914198
# Text: "The island, and it was there " Prob (beyond starting) 0.000000020359625587574133965769
# Text: "The island, and it was theref" Prob (beyond starting) 0.000000018491415090513583285269
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessa" Prob (beyond starting) 0.000000153320353566732866362597
# Text: "The island, and that is to say" Prob (beyond starting) 0.000000030447655711683079289243
# Text: "The island, and it was therefo" Prob (beyond starting) 0.000000018402059621512165985046
# Text: "The island, and that is to be " Prob (beyond starting) 0.000000015369679100027869302418
# Text: "The island, and it was there w" Prob (beyond starting) 0.000000006263265649167558396804
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessar" Prob (beyond starting) 0.000000152024380545919445244178
# Text: "The island, and it was therefor" Prob (beyond starting) 0.000000018085692396889703460052
# Text: "The island, and that is to say," Prob (beyond starting) 0.000000013691599299554593781165
# Text: "The island, and that is to say " Prob (beyond starting) 0.000000013242337464759689322885
# Text: "The island, and it was there wa" Prob (beyond starting) 0.000000002904640619469246882912
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary" Prob (beyond starting) 0.000000150955421062497408813248
# Text: "The island, and it was therefore" Prob (beyond starting) 0.000000017986524745911925254024
# Text: "The island, and that is to say, " Prob (beyond starting) 0.000000010136494858898432154721
# Text: "The island, and that is to say t" Prob (beyond starting) 0.000000006149802997271163963106
# Text: "The island, and it was there was" Prob (beyond starting) 0.000000002887440146783889264895
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary " Prob (beyond starting) 0.000000085852498218826964992878
# Text: "The island, and it was necessary," Prob (beyond starting) 0.000000032635413941503878546033
# Text: "The island, and it was necessary
# " Prob (beyond starting) 0.000000010885341015218984114873
# Text: "The island, and it was necessary." Prob (beyond starting) 0.000000009115800751279366056335
# Text: "The island, and it was therefore," Prob (beyond starting) 0.000000008196487381770119780239
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary t" Prob (beyond starting) 0.000000074463042138741088351389
# Text: "The island, and it was necessary, " Prob (beyond starting) 0.000000026059201063750922137171
# Text: "The island, and it was necessary
# t" Prob (beyond starting) 0.000000009332118810977039375275
# Text: "The island, and it was therefore, " Prob (beyond starting) 0.000000006776567431265443055593
# Text: "The island, and it was necessary.
# " Prob (beyond starting) 0.000000004970052386586001769713
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to" Prob (beyond starting) 0.000000070019377389698925655528
# Text: "The island, and it was necessary
# to" Prob (beyond starting) 0.000000009162948592846761318532
# Text: "The island, and it was necessary, a" Prob (beyond starting) 0.000000007685075851104503685086
# Text: "The island, and it was necessary, t" Prob (beyond starting) 0.000000004342526196479890638945
# Text: "The island, and it was necessary.
#
# " Prob (beyond starting) 0.000000004047776642822160110245
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to " Prob (beyond starting) 0.000000064594049391545170342288
# Text: "The island, and it was necessary
# to " Prob (beyond starting) 0.000000008682800866623237591065
# Text: "The island, and it was necessary, an" Prob (beyond starting) 0.000000006181212856826443743217
# Text: "The island, and it was necessary to
# " Prob (beyond starting) 0.000000004671811379932329352600
# Text: "The island, and it was necessary, th" Prob (beyond starting) 0.000000003549871750474354171845
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to s" Prob (beyond starting) 0.000000007804981729516860058880
# Text: "The island, and it was necessary to c" Prob (beyond starting) 0.000000007732059290046290904620
# Text: "The island, and it was necessary to t" Prob (beyond starting) 0.000000007276109599245034208294
# Text: "The island, and it was necessary to b" Prob (beyond starting) 0.000000006958499969495154695307
# Text: "The island, and it was necessary, and" Prob (beyond starting) 0.000000006122231795616777810004
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to th" Prob (beyond starting) 0.000000005495615549537454580814
# Text: "The island, and it was necessary, and " Prob (beyond starting) 0.000000005008569219276330332306
# Text: "The island, and it was necessary to be" Prob (beyond starting) 0.000000004886702439432799567512
# Text: "The island, and it was necessary to co" Prob (beyond starting) 0.000000002932344695526080413570
# Text: "The island, and it was necessary to sa" Prob (beyond starting) 0.000000002026371775721058355393
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the" Prob (beyond starting) 0.000000004778779267596585132288
# Text: "The island, and it was necessary to be " Prob (beyond starting) 0.000000003181580108226947830468
# Text: "The island, and it was necessary to say" Prob (beyond starting) 0.000000001569401050746806473323
# Text: "The island, and it was necessary, and t" Prob (beyond starting) 0.000000001385021126791774729967
# Text: "The island, and it was necessary to con" Prob (beyond starting) 0.000000001137447141490484249600
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the " Prob (beyond starting) 0.000000003251250761883774381909
# Text: "The island, and it was necessary, and th" Prob (beyond starting) 0.000000001258013014219404308463
# Text: "The island, and it was necessary to the
# " Prob (beyond starting) 0.000000000899397504487119034790
# Text: "The island, and it was necessary to say " Prob (beyond starting) 0.000000000732254702406827036742
# Text: "The island, and it was necessary to say," Prob (beyond starting) 0.000000000632877731861095074334
# Insert anything to continue ...
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary, and the" Prob (beyond starting) 0.000000000846809569082670599677
# Text: "The island, and it was necessary to the s" Prob (beyond starting) 0.000000000543338836331576726330
# Text: "The island, and it was necessary to say, " Prob (beyond starting) 0.000000000464360899286257710992
# Text: "The island, and it was necessary to the c" Prob (beyond starting) 0.000000000406247994870380518928
# Text: "The island, and it was necessary to say t" Prob (beyond starting) 0.000000000375819508009124113556
