# %%
from tqdm import tqdm
import torch.nn as nn
import numpy as np
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# Fill in the code below to make Beam Search work.
FILL_IN = "FILL IN"

# %% [markdown]
# ### Get the data and process
# - This is the Mysterious island found in Project Gutenberg.

# %%
## Reading and processing text
with open('1268-0-1.txt', 'r', encoding="utf8") as fp:
    text=fp.read()
    
start_indx = text.find('THE MYSTERIOUS ISLAND')
end_indx = text.find('End of the Project Gutenberg')

text = text[start_indx:end_indx]
char_set = set(text)
print('Total Length:', len(text))
print('Unique Characters:', len(char_set))
assert(len(text) == 1130711)
assert(len(char_set) == 85)
# Out:
# Total Length: 1130711
# Unique Characters: 85

# %% [markdown]
# ### Tokenze and get other helpers
# - We do this manually since everything is character based.

# %%
# The universe of words.
chars_sorted = sorted(char_set)

# Effectively, these maps are the tokenizer.
char2int = {ch:i for i,ch in enumerate(chars_sorted)}
int2char = np.array(chars_sorted)

# Tokenize the entire corpus.
text_encoded = np.array(
    [char2int[ch] for ch in text],
    dtype=np.int32)

print('Text encoded shape: ', text_encoded.shape)

print(text[:15], '     == Encoding ==> ', text_encoded[:15])
print(text_encoded[15:21], ' == Reverse  ==> ', ''.join(int2char[text_encoded[15:21]]))
# Out:
# Text encoded shape:  (1130711,)
# THE MYSTERIOUS       == Encoding ==>  [48 36 33  1 41 53 47 48 33 46 37 43 49 47  1]
# [37 47 40 29 42 32]  == Reverse  ==>  ISLAND

# %% [markdown]
# ### Load the model

# %%
device = torch.device("mps")

# %%
# !du -h hw7_model.pt
# Out:
# 6.3M	hw7_model.pt

# %%
# Lost a traced version of this model.
# Note this is the same as the HW 7 model but a little different
# The HW7 model had an if-else in its forward method, and this is not allowed.
# The forward method of this model takes hidden and cell, which could be all zeros but the user has to specify.
model = torch.jit.load('hw7_model.pt')

# %%
model
# Out:
# RecursiveScriptModule(
#   original_name=RNN
#   (embedding): RecursiveScriptModule(original_name=Embedding)
#   (rnn): RecursiveScriptModule(original_name=LSTM)
#   (fc): RecursiveScriptModule(original_name=Linear)
# )

# %%
# 'jit' does not save other methods on a model, we need to define this helper and use it below.
def init_hidden(model, batch_size):
    return (
        torch.zeros(1, batch_size, model.rnn_hidden_size),
        torch.zeros(1, batch_size, model.rnn_hidden_size)
    )

# %% [markdown]
# ### Beam search algorithm.
# - Good article: https://towardsdatascience.com/foundations-of-nlp-explained-visually-beam-search-how-it-works-1586b9849a24

# %%
from numpy import squeeze


def beam_search_decoding(
    model,
    starting_str, 
    len_generated_text=500, 
    beams=5,
    print_paths=True
):
    assert(len(starting_str) != 0)

    # Get the encoding of the starting_str as a tensor of ints.
    encoded_input = torch.tensor([char2int[ch] for ch in starting_str]).to(device)
    
    # Reshape the above to be of appropiate dimension.
    encoded_input = encoded_input.reshape(1, -1)

    # Put the model in eval mode.
    model.eval()
    
    # Unfortunately, jit save does not save methods other than forward.
    # Use init_hidden to get the first hidden and cell states.
    hidden, cell = init_hidden(model, 1)
    
    hidden = hidden.to(device)
    
    cell = cell.to(device)
    
    generated_log_prob = 0
    generated_str = starting_str[0]
        
    # Build up the starting hidden and cell states.
    # You can do this all in one go?
    for i in range(len(starting_str)-1):
        # Feed each letter 1 by 1 and then get the final hidden state.
        # Get the character at index i and push it through the model.
        # Get the logits, the hidden and cell states, which would will need later.
        out = encoded_input[:, i].unsqueeze(0)
        logits, (hidden, cell) = model(out, hidden, cell)
        logits = logits.squeeze()
        # Get the probability of the generated character.
        # For input of index i, we want the probability that the model generated i+1.
        # We push the startiing_str[i] into the model, and append starting_str[i+1] to generated_str.
        generated_str += starting_str[i+1]
        
        # Get the probabilities of the different characters that the model this. 
        # You need to apply Softmax to the logits.
        probs = nn.Softmax(dim=0)(logits)
        # Add the log probability of the  appened char (int) to the running generated log probability.
        generated_log_prob += torch.log(probs[encoded_input[:,i+1].item()])
    
    # Get the last character in the encoded input.
    last_char_int = encoded_input[:, -1].unsqueeze(0)
    
    # Push this through the model.
    logits, (hidden, cell) = model(last_char_int, hidden, cell)
    # As before, get the probaility per character.
    probs = nn.Softmax(dim=0)(logits.squeeze())
    
    new_beams = []
    
    for j, prob in enumerate(probs):
        # For each probability, append the tuple (hidden, cell, the generatd str with the jth index char, generated str's the log probablity)
        # Note this is the running generated str and generated log probability.
        new_beams.append(
            (hidden, cell, generated_str + int2char[j], generated_log_prob + torch.log(prob))
        ) 
    # Sort the beams from most proable to least. Use -log(generated_prob).
    new_beams = sorted(new_beams, key = lambda x: x[-1],reverse=True)
    
    beam_to_beam_data = {}
    
    # Add the top "beams" = 5 beams to the hash map.
    # We should have a map going {beam_id -> (hidden, cell, generated_str, geenrated_log_prob)}
    for beam in range(beams):
        beam_to_beam_data[beam] = new_beams[beam]
    
    # For each index of generated text.
    for i in range(len_generated_text):
        # Define new beams.
        new_beams = []
        
        # For each beam.
        for beam in range(beams):
            
            # Grab the 4 elements associated with this beam from beam_to_beam_data.
            hidden, cell, generated_str, generated_log_prob = beam_to_beam_data[beam]
            
            # Get the last char in the str that's in the beam.
            last_char_int = torch.tensor([char2int[generated_str[-1]]]).unsqueeze(0).to(device)
            
            # Push hidden, cell and the last_char_int through the model.
            logits, (hidden, cell) = model(last_char_int, hidden, cell)
            
            # Get the probabilities.
            probs = nn.Softmax(dim=0)(logits.squeeze())
            
            # As before, append the 4 elements associated with this new beam to new beams.
            for j, prob in enumerate(probs):
                new_beams.append(
                    (hidden, cell, generated_str + int2char[j], generated_log_prob + torch.log(prob))
                )
           
        # Sort the beams from most probable to least. Use -log(p).
        new_beams = sorted(new_beams, key = lambda x: x[-1],reverse=True)
        # The number of beams considered should always satisfy this.
        # Except for the first iteration.
        assert(len(new_beams) == beams * len(char2int))
        
        # Leave this to true.
        if print_paths:
            print("The first 5 paths beam paths and the associated data for them: ")
            for beam in range(5):
                generated_str, generated_log_prob = new_beams[beam][2:]
                print("Text: \"{}\" Prob {:0.30f}".format(
                        generated_str, torch.exp(generated_log_prob)
                ))
            #_ = input("Insert anything to continue ...")
            print("\n")
                
        # Update the beams to be equal to the top beams.
        for beam in range(beams):
            beam_to_beam_data[beam] = new_beams[beam]
            
    generated_strs = []
    generated_log_probs = []
    
    # Grab the top beams, and return them.
    for beam in range(beams):
        (_, _, generated_str, generated_log_prob) = beam_to_beam_data[beam]
        generated_strs.append(generated_str)
        generated_log_probs.append(generated_log_prob)        
                
    return generated_strs, [torch.exp(_) for _ in generated_log_probs]

# %%
torch.manual_seed(1)
model.to(device)
beams=5
len_generated_text=500

generated_strs, generated_probs = beam_search_decoding(
    model,
    starting_str="The island",
    len_generated_text=len_generated_text,
    beams=beams
)

for beam in range(beams):
    print(f"Beam {beam} information: ")
    print(generated_strs[beam])
    print(generated_probs[beam])
# Out:
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, " Prob 0.000520036090165376663208007812
# Text: "The island w" Prob 0.000227798998821526765823364258
# Text: "The island?”" Prob 0.000097528572950977832078933716
# Text: "The island o" Prob 0.000093910733994562178850173950
# Text: "The island i" Prob 0.000063718616729602217674255371
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island wa" Prob 0.000172444022609852254390716553
# Text: "The island, w" Prob 0.000092942558694630861282348633
# Text: "The island, a" Prob 0.000090473193267825990915298462
# Text: "The island, t" Prob 0.000070329275331459939479827881
# Text: "The island?”
# " Prob 0.000062701823480892926454544067
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island was" Prob 0.000168390441103838384151458740
# Text: "The island, an" Prob 0.000071394635597243905067443848
# Text: "The island, th" Prob 0.000063585910538677126169204712
# Text: "The island?”
#
# " Prob 0.000062353756220545619726181030
# Text: "The island, wh" Prob 0.000055470434745075181126594543
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island was " Prob 0.000162886397447437047958374023
# Text: "The island, and" Prob 0.000070902024162933230400085449
# Text: "The island?”
#
# “" Prob 0.000043470892705954611301422119
# Text: "The island, the" Prob 0.000041231316572520881891250610
# Text: "The island, who" Prob 0.000031136489269556477665901184
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and " Prob 0.000066633925598580390214920044
# Text: "The island, the " Prob 0.000022295342205325141549110413
# Text: "The island was s" Prob 0.000017944506907952018082141876
# Text: "The island, who " Prob 0.000017057418517651967704296112
# Text: "The island was n" Prob 0.000016321579096256755292415619
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and t" Prob 0.000017958438547793775796890259
# Text: "The island was no" Prob 0.000013530763681046664714813232
# Text: "The island was st" Prob 0.000005924825927650090306997299
# Text: "The island, and w" Prob 0.000005824259005748899653553963
# Text: "The island, and i" Prob 0.000005722356945625506341457367
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and th" Prob 0.000016444007997051812708377838
# Text: "The island was not" Prob 0.000011276333680143579840660095
# Text: "The island, and it" Prob 0.000004401440946821821853518486
# Text: "The island was sti" Prob 0.000002779731175905908457934856
# Text: "The island, and wh" Prob 0.000001813161475183733273297548
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and the" Prob 0.000010454577932250685989856720
# Text: "The island was not " Prob 0.000009205838978232350200414658
# Text: "The island, and it " Prob 0.000004100525529793230816721916
# Text: "The island, and tha" Prob 0.000003410586487007094547152519
# Text: "The island was stil" Prob 0.000002749086434050695970654488
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and the " Prob 0.000005812351446365937590599060
# Text: "The island, and that" Prob 0.000003384762294444954022765160
# Text: "The island, and it w" Prob 0.000003218235860913409851491451
# Text: "The island was still" Prob 0.000002747603957686806097626686
# Text: "The island, and they" Prob 0.000001530515646663843654096127
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and that " Prob 0.000003094650082857697270810604
# Text: "The island was still " Prob 0.000002619106226120493374764919
# Text: "The island, and it wa" Prob 0.000002332776602997910231351852
# Text: "The island, and they " Prob 0.000001463771695853210985660553
# Text: "The island, and the s" Prob 0.000000840403117763344198465347
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was" Prob 0.000002320181238246732391417027
# Text: "The island, and that t" Prob 0.000001036605453919037245213985
# Text: "The island was still t" Prob 0.000000548207424344582250341773
# Text: "The island, and that i" Prob 0.000000465100043811617069877684
# Text: "The island, and they w" Prob 0.000000397746248381736222654581
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was " Prob 0.000002180168394261272624135017
# Text: "The island, and that th" Prob 0.000000995321784102998208254576
# Text: "The island was still th" Prob 0.000000319188842468065558932722
# Text: "The island, and that is" Prob 0.000000311662887497732299380004
# Text: "The island, and they we" Prob 0.000000187845458299307210836560
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and that the" Prob 0.000000811752727258863160386682
# Text: "The island, and it was n" Prob 0.000000460740096741574234329164
# Text: "The island, and it was t" Prob 0.000000319451856967134517617524
# Text: "The island, and that is " Prob 0.000000243905446950520854443312
# Text: "The island was still the" Prob 0.000000200740188915915496181697
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and that the " Prob 0.000000567760253034066408872604
# Text: "The island, and it was th" Prob 0.000000259080081832507858052850
# Text: "The island, and it was no" Prob 0.000000249608689273372874595225
# Text: "The island, and it was ne" Prob 0.000000203408788479464419651777
# Text: "The island, and that is t" Prob 0.000000162549426363511884119362
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was not" Prob 0.000000223616751782174105755985
# Text: "The island, and it was the" Prob 0.000000194868121639046876225621
# Text: "The island, and it was nec" Prob 0.000000158633923774686991237104
# Text: "The island, and that is to" Prob 0.000000140876863952144049108028
# Text: "The island, and that the s" Prob 0.000000091169269467172853183001
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was not " Prob 0.000000193269414694441366009414
# Text: "The island, and it was nece" Prob 0.000000157543340151278243865818
# Text: "The island, and that is to " Prob 0.000000127732107557676499709487
# Text: "The island, and it was the " Prob 0.000000082837928516710235271603
# Text: "The island, and it was ther" Prob 0.000000054961819984100657165982
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was neces" Prob 0.000000156561227981910633388907
# Text: "The island, and it was there" Prob 0.000000053868070892804098548368
# Text: "The island, and that is to s" Prob 0.000000042620442286533943843096
# Text: "The island, and it was not a" Prob 0.000000026380078566035081166774
# Text: "The island, and that is to b" Prob 0.000000023313491581689049780834
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necess" Prob 0.000000155033319515496259555221
# Text: "The island, and that is to sa" Prob 0.000000036562280314456074847840
# Text: "The island, and that is to be" Prob 0.000000020992670712871586147230
# Text: "The island, and it was there " Prob 0.000000020359658847723949293140
# Text: "The island, and it was theref" Prob 0.000000018491450148871990677435
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessa" Prob 0.000000153320527829237107653171
# Text: "The island, and that is to say" Prob 0.000000030447740329009320703335
# Text: "The island, and it was therefo" Prob 0.000000018402069201783888274804
# Text: "The island, and that is to be " Prob 0.000000015369741035442530119326
# Text: "The island, and it was there w" Prob 0.000000006263269458628428765223
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessar" Prob 0.000000152024682620321982540190
# Text: "The island, and it was therefor" Prob 0.000000018085698272329864266794
# Text: "The island, and that is to say," Prob 0.000000013691621170153212005971
# Text: "The island, and that is to say " Prob 0.000000013242369867327852261951
# Text: "The island, and it was there wa" Prob 0.000000002904643414680663227045
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary" Prob 0.000000150955585809242620598525
# Text: "The island, and it was therefore" Prob 0.000000017986526046342987683602
# Text: "The island, and that is to say, " Prob 0.000000010136518291403717739740
# Text: "The island, and that is to say t" Prob 0.000000006149823317258551469422
# Text: "The island, and it was there was" Prob 0.000000002887440953003306276514
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary " Prob 0.000000085852633446847903542221
# Text: "The island, and it was necessary," Prob 0.000000032635504965128347976133
# Text: "The island, and it was necessary
# " Prob 0.000000010885375267832841927884
# Text: "The island, and it was necessary." Prob 0.000000009115805887915939820232
# Text: "The island, and it was therefore," Prob 0.000000008196467504717475094367
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary t" Prob 0.000000074463159194237960036844
# Text: "The island, and it was necessary, " Prob 0.000000026059263191768877732102
# Text: "The island, and it was necessary
# t" Prob 0.000000009332143946494397823699
# Text: "The island, and it was therefore, " Prob 0.000000006776554428711278887931
# Text: "The island, and it was necessary.
# " Prob 0.000000004970054146014035723056
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to" Prob 0.000000070019410713939578272402
# Text: "The island, and it was necessary
# to" Prob 0.000000009162977931964633171447
# Text: "The island, and it was necessary, a" Prob 0.000000007685083680541993089719
# Text: "The island, and it was necessary, t" Prob 0.000000004342537884838293393841
# Text: "The island, and it was necessary.
#
# " Prob 0.000000004047778556781622683047
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to " Prob 0.000000064594033233333902899176
# Text: "The island, and it was necessary
# to " Prob 0.000000008682836671880522771971
# Text: "The island, and it was necessary, an" Prob 0.000000006181221756662580446573
# Text: "The island, and it was necessary to
# " Prob 0.000000004671818487622658722103
# Text: "The island, and it was necessary, th" Prob 0.000000003549885940756780655647
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to s" Prob 0.000000007804985990844670595834
# Text: "The island, and it was necessary to c" Prob 0.000000007732054996267834212631
# Text: "The island, and it was necessary to t" Prob 0.000000007276119262655811326113
# Text: "The island, and it was necessary to b" Prob 0.000000006958494669362380591338
# Text: "The island, and it was necessary, and" Prob 0.000000006122233386918196629267
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to th" Prob 0.000000005495622623641338577727
# Text: "The island, and it was necessary, and " Prob 0.000000005008569115005911953631
# Text: "The island, and it was necessary to be" Prob 0.000000004886707483109375971253
# Text: "The island, and it was necessary to co" Prob 0.000000002932347031858739683230
# Text: "The island, and it was necessary to sa" Prob 0.000000002026376622055181542237
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the" Prob 0.000000004778791140580551655148
# Text: "The island, and it was necessary to be " Prob 0.000000003181583441147495250334
# Text: "The island, and it was necessary to say" Prob 0.000000001569404828316578459635
# Text: "The island, and it was necessary, and t" Prob 0.000000001385021430877486636746
# Text: "The island, and it was necessary to con" Prob 0.000000001137448357724224479171
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the " Prob 0.000000003251259705905340524623
# Text: "The island, and it was necessary, and th" Prob 0.000000001258012916061090891162
# Text: "The island, and it was necessary to the
# " Prob 0.000000000899401275678002321001
# Text: "The island, and it was necessary to say " Prob 0.000000000732255645008450528621
# Text: "The island, and it was necessary to say," Prob 0.000000000632878582873530604047
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary, and the" Prob 0.000000000846809566912298805619
# Text: "The island, and it was necessary to the s" Prob 0.000000000543340650249746204281
# Text: "The island, and it was necessary to say, " Prob 0.000000000464362215346625362145
# Text: "The island, and it was necessary to the c" Prob 0.000000000406249534012914637060
# Text: "The island, and it was necessary to say t" Prob 0.000000000375820152775929727795
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary, and the " Prob 0.000000000404267674891656270120
# Text: "The island, and it was necessary to say th" Prob 0.000000000312558368076309989192
# Text: "The island, and it was necessary to the co" Prob 0.000000000299062469233390970658
# Text: "The island, and it was necessary to say, t" Prob 0.000000000187821147523692388859
# Text: "The island, and it was necessary to the sa" Prob 0.000000000149762119372454094446
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to say tha" Prob 0.000000000245194198278397834656
# Text: "The island, and it was necessary to say, th" Prob 0.000000000141290965038898264083
# Text: "The island, and it was necessary to the cor" Prob 0.000000000110734067748641251683
# Text: "The island, and it was necessary to the sam" Prob 0.000000000103519089134085362502
# Text: "The island, and it was necessary to the col" Prob 0.000000000079278077158573267980
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to say that" Prob 0.000000000241595410344075389730
# Text: "The island, and it was necessary to say, the" Prob 0.000000000102903414955779481943
# Text: "The island, and it was necessary to the corr" Prob 0.000000000101945243913270644498
# Text: "The island, and it was necessary to the same" Prob 0.000000000101830203991237766559
# Text: "The island, and it was necessary to the colo" Prob 0.000000000047639739375604506222
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to say that " Prob 0.000000000214292777966917924459
# Text: "The island, and it was necessary to the corra" Prob 0.000000000101518349282514463994
# Text: "The island, and it was necessary to the same " Prob 0.000000000073617535678582868286
# Text: "The island, and it was necessary to say, the " Prob 0.000000000054423573286888071721
# Text: "The island, and it was necessary to the colon" Prob 0.000000000044332353760223597305
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the corral" Prob 0.000000000101215209824534468908
# Text: "The island, and it was necessary to say that t" Prob 0.000000000093248186949779210408
# Text: "The island, and it was necessary to the same t" Prob 0.000000000043223705864514627706
# Text: "The island, and it was necessary to the colony" Prob 0.000000000022239560887316045523
# Text: "The island, and it was necessary to say that i" Prob 0.000000000022001858668296847554
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to say that th" Prob 0.000000000091269138080551925896
# Text: "The island, and it was necessary to the same ti" Prob 0.000000000031773972342108436351
# Text: "The island, and it was necessary to the corral " Prob 0.000000000031621347901245044909
# Text: "The island, and it was necessary to the corral!" Prob 0.000000000021252406084970587585
# Text: "The island, and it was necessary to the corral," Prob 0.000000000020801629516120634378
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to say that the" Prob 0.000000000077423158162392979875
# Text: "The island, and it was necessary to the same tim" Prob 0.000000000031050891025063975803
# Text: "The island, and it was necessary to the corral, " Prob 0.000000000016393738797026990994
# Text: "The island, and it was necessary to the corral w" Prob 0.000000000012883418290532411277
# Text: "The island, and it was necessary to say that thi" Prob 0.000000000012442363979403570085
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to say that the " Prob 0.000000000047710835282543939684
# Text: "The island, and it was necessary to the same time" Prob 0.000000000030860258792841932518
# Text: "The island, and it was necessary to say that the
# " Prob 0.000000000012208987293371720284
# Text: "The island, and it was necessary to say that this" Prob 0.000000000012196113043094758410
# Text: "The island, and it was necessary to say that they" Prob 0.000000000010376724653149427269
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time " Prob 0.000000000013389722490486644091
# Text: "The island, and it was necessary to the same time," Prob 0.000000000011319908552187563089
# Text: "The island, and it was necessary to say that this " Prob 0.000000000010759994457931743028
# Text: "The island, and it was necessary to say that they " Prob 0.000000000008591271791202892416
# Text: "The island, and it was necessary to say that the s" Prob 0.000000000007882002342474159207
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, " Prob 0.000000000009734176138753714014
# Text: "The island, and it was necessary to the same time a" Prob 0.000000000004085462003422524191
# Text: "The island, and it was necessary to the same time t" Prob 0.000000000002984112089376989019
# Text: "The island, and it was necessary to say that the se" Prob 0.000000000002596651626357582288
# Text: "The island, and it was necessary to say that they w" Prob 0.000000000002203833686723055685
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, a" Prob 0.000000000002355633700254489149
# Text: "The island, and it was necessary to the same time to" Prob 0.000000000001581307892788152980
# Text: "The island, and it was necessary to the same time an" Prob 0.000000000001384704850782014773
# Text: "The island, and it was necessary to the same time th" Prob 0.000000000001375348836554768361
# Text: "The island, and it was necessary to say that the sea" Prob 0.000000000001218001611028030062
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, an" Prob 0.000000000001699599228716097699
# Text: "The island, and it was necessary to the same time to " Prob 0.000000000001347298683208875136
# Text: "The island, and it was necessary to the same time and" Prob 0.000000000000989550238625347411
# Text: "The island, and it was necessary to the same time the" Prob 0.000000000000955999819238217974
# Text: "The island, and it was necessary to say that the sea " Prob 0.000000000000336065837701696180
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and" Prob 0.000000000001692455420601590710
# Text: "The island, and it was necessary to the same time and " Prob 0.000000000000823241594252038800
# Text: "The island, and it was necessary to the same time the " Prob 0.000000000000489630525794121363
# Text: "The island, and it was necessary to the same time to t" Prob 0.000000000000223418234867461818
# Text: "The island, and it was necessary to the same time they" Prob 0.000000000000178156832819284516
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and " Prob 0.000000000001300796493089451111
# Text: "The island, and it was necessary to the same time, and
# " Prob 0.000000000000365412181849850137
# Text: "The island, and it was necessary to the same time to th" Prob 0.000000000000188505529003131500
# Text: "The island, and it was necessary to the same time they " Prob 0.000000000000150511832272721968
# Text: "The island, and it was necessary to the same time and t" Prob 0.000000000000140077755167791751
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and t" Prob 0.000000000000375738231760819330
# Text: "The island, and it was necessary to the same time to the" Prob 0.000000000000177822681709724484
# Text: "The island, and it was necessary to the same time, and w" Prob 0.000000000000136035564865695513
# Text: "The island, and it was necessary to the same time and th" Prob 0.000000000000122040507040399593
# Text: "The island, and it was necessary to the same time, and h" Prob 0.000000000000107372871173665868
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and th" Prob 0.000000000000349971733450832323
# Text: "The island, and it was necessary to the same time to the " Prob 0.000000000000122592257525977466
# Text: "The island, and it was necessary to the same time and the" Prob 0.000000000000101424592465967911
# Text: "The island, and it was necessary to the same time, and he" Prob 0.000000000000056656895429559040
# Text: "The island, and it was necessary to the same time, and wh" Prob 0.000000000000043741147314445283
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the" Prob 0.000000000000258306884996090114
# Text: "The island, and it was necessary to the same time and the " Prob 0.000000000000065386159485945894
# Text: "The island, and it was necessary to the same time, and he " Prob 0.000000000000046622929583857442
# Text: "The island, and it was necessary to the same time, and tha" Prob 0.000000000000042968856554456702
# Text: "The island, and it was necessary to the same time, and thi" Prob 0.000000000000037038545109635904
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the " Prob 0.000000000000135188965599310207
# Text: "The island, and it was necessary to the same time, and that" Prob 0.000000000000042651906989989510
# Text: "The island, and it was necessary to the same time, and the
# " Prob 0.000000000000037536536108117441
# Text: "The island, and it was necessary to the same time, and they" Prob 0.000000000000035915562380693308
# Text: "The island, and it was necessary to the same time, and this" Prob 0.000000000000035655638462367065
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and that " Prob 0.000000000000036998707456060639
# Text: "The island, and it was necessary to the same time, and they " Prob 0.000000000000030007124714702404
# Text: "The island, and it was necessary to the same time, and this " Prob 0.000000000000028911582465119059
# Text: "The island, and it was necessary to the same time, and the s" Prob 0.000000000000020733294706196288
# Text: "The island, and it was necessary to the same time, and the c" Prob 0.000000000000015541568886326927
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and that t" Prob 0.000000000000013194891211013200
# Text: "The island, and it was necessary to the same time, and they w" Prob 0.000000000000009017697409651783
# Text: "The island, and it was necessary to the same time, and the co" Prob 0.000000000000008160378094286026
# Text: "The island, and it was necessary to the same time, and this w" Prob 0.000000000000006859909775641659
# Text: "The island, and it was necessary to the same time, and the se" Prob 0.000000000000006448194165035656
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and that th" Prob 0.000000000000012767524972640779
# Text: "The island, and it was necessary to the same time, and this wa" Prob 0.000000000000005492900666243363
# Text: "The island, and it was necessary to the same time, and the col" Prob 0.000000000000004807123310388494
# Text: "The island, and it was necessary to the same time, and they we" Prob 0.000000000000004414765367242567
# Text: "The island, and it was necessary to the same time, and the set" Prob 0.000000000000003733811440505838
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and that the" Prob 0.000000000000011132299915879093
# Text: "The island, and it was necessary to the same time, and they wer" Prob 0.000000000000004245158030983208
# Text: "The island, and it was necessary to the same time, and this was" Prob 0.000000000000003999870418469045
# Text: "The island, and it was necessary to the same time, and the sett" Prob 0.000000000000003716416771901024
# Text: "The island, and it was necessary to the same time, and the colo" Prob 0.000000000000003019675845093370
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and that the " Prob 0.000000000000007000175890608130
# Text: "The island, and it was necessary to the same time, and they were" Prob 0.000000000000004239560413751278
# Text: "The island, and it was necessary to the same time, and this was " Prob 0.000000000000003737011530980565
# Text: "The island, and it was necessary to the same time, and the settl" Prob 0.000000000000003700404461066129
# Text: "The island, and it was necessary to the same time, and the colon" Prob 0.000000000000002942892308424767
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the settle" Prob 0.000000000000003693884001438165
# Text: "The island, and it was necessary to the same time, and they were " Prob 0.000000000000003672458303037368
# Text: "The island, and it was necessary to the same time, and the coloni" Prob 0.000000000000002568378808378647
# Text: "The island, and it was necessary to the same time, and that the s" Prob 0.000000000000001144477989924186
# Text: "The island, and it was necessary to the same time, and that the c" Prob 0.000000000000000897119064216631
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the settler" Prob 0.000000000000003662218521738011
# Text: "The island, and it was necessary to the same time, and the colonis" Prob 0.000000000000002535450614312373
# Text: "The island, and it was necessary to the same time, and they were t" Prob 0.000000000000000477305977453554
# Text: "The island, and it was necessary to the same time, and that the co" Prob 0.000000000000000461979710366376
# Text: "The island, and it was necessary to the same time, and that the se" Prob 0.000000000000000395394450382715
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the settlers" Prob 0.000000000000003652296801310347
# Text: "The island, and it was necessary to the same time, and the colonist" Prob 0.000000000000002526930733412415
# Text: "The island, and it was necessary to the same time, and they were th" Prob 0.000000000000000287372788605628
# Text: "The island, and it was necessary to the same time, and that the set" Prob 0.000000000000000202789415216683
# Text: "The island, and it was necessary to the same time, and that the col" Prob 0.000000000000000193730239027121
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the settlers " Prob 0.000000000000002948274144013384
# Text: "The island, and it was necessary to the same time, and the colonists" Prob 0.000000000000002492477033008136
# Text: "The island, and it was necessary to the same time, and the settlers," Prob 0.000000000000000357561882612280
# Text: "The island, and it was necessary to the same time, and they were the" Prob 0.000000000000000220459766576049
# Text: "The island, and it was necessary to the same time, and that the sett" Prob 0.000000000000000201737440000863
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists " Prob 0.000000000000001472547614681170
# Text: "The island, and it was necessary to the same time, and the settlers w" Prob 0.000000000000000619164408481744
# Text: "The island, and it was necessary to the same time, and the colonists’" Prob 0.000000000000000535077330225442
# Text: "The island, and it was necessary to the same time, and the settlers h" Prob 0.000000000000000415114621474437
# Text: "The island, and it was necessary to the same time, and the settlers a" Prob 0.000000000000000345030797781261
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists’ " Prob 0.000000000000000508610938755534
# Text: "The island, and it was necessary to the same time, and the colonists w" Prob 0.000000000000000438820161992328
# Text: "The island, and it was necessary to the same time, and the settlers ha" Prob 0.000000000000000363101186919747
# Text: "The island, and it was necessary to the same time, and the colonists h" Prob 0.000000000000000349636486492397
# Text: "The island, and it was necessary to the same time, and the settlers we" Prob 0.000000000000000299435623035493
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the settlers had" Prob 0.000000000000000342966949065716
# Text: "The island, and it was necessary to the same time, and the colonists ha" Prob 0.000000000000000310885655597799
# Text: "The island, and it was necessary to the same time, and the settlers wer" Prob 0.000000000000000281662965977966
# Text: "The island, and it was necessary to the same time, and the colonists we" Prob 0.000000000000000212291867570345
# Text: "The island, and it was necessary to the same time, and the colonists wo" Prob 0.000000000000000093521066525025
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the settlers had " Prob 0.000000000000000293369755402409
# Text: "The island, and it was necessary to the same time, and the settlers were" Prob 0.000000000000000281614579220854
# Text: "The island, and it was necessary to the same time, and the colonists had" Prob 0.000000000000000276238196406835
# Text: "The island, and it was necessary to the same time, and the colonists wer" Prob 0.000000000000000202297778765251
# Text: "The island, and it was necessary to the same time, and the colonists wou" Prob 0.000000000000000086366099810229
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists had " Prob 0.000000000000000234093066264572
# Text: "The island, and it was necessary to the same time, and the settlers were " Prob 0.000000000000000229605141602884
# Text: "The island, and it was necessary to the same time, and the colonists were" Prob 0.000000000000000202240551101752
# Text: "The island, and it was necessary to the same time, and the colonists woul" Prob 0.000000000000000085534770059723
# Text: "The island, and it was necessary to the same time, and the settlers had b" Prob 0.000000000000000067991268501654
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists were " Prob 0.000000000000000165343332698212
# Text: "The island, and it was necessary to the same time, and the colonists would" Prob 0.000000000000000085448419021218
# Text: "The island, and it was necessary to the same time, and the settlers had be" Prob 0.000000000000000063199417830579
# Text: "The island, and it was necessary to the same time, and the colonists had b" Prob 0.000000000000000050727390386574
# Text: "The island, and it was necessary to the same time, and the colonists had n" Prob 0.000000000000000043613825715797
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would " Prob 0.000000000000000073268005830362
# Text: "The island, and it was necessary to the same time, and the settlers had bee" Prob 0.000000000000000054119509186144
# Text: "The island, and it was necessary to the same time, and the colonists had be" Prob 0.000000000000000047006731991310
# Text: "The island, and it was necessary to the same time, and the colonists had no" Prob 0.000000000000000040252279511668
# Text: "The island, and it was necessary to the same time, and the colonists were n" Prob 0.000000000000000016002763516265
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the settlers had been" Prob 0.000000000000000053869806520271
# Text: "The island, and it was necessary to the same time, and the colonists had bee" Prob 0.000000000000000040560728544644
# Text: "The island, and it was necessary to the same time, and the colonists had not" Prob 0.000000000000000037959788148646
# Text: "The island, and it was necessary to the same time, and the colonists would h" Prob 0.000000000000000019730634926470
# Text: "The island, and it was necessary to the same time, and the colonists would b" Prob 0.000000000000000012918454339058
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the settlers had been " Prob 0.000000000000000045334275363124
# Text: "The island, and it was necessary to the same time, and the colonists had been" Prob 0.000000000000000040393657913243
# Text: "The island, and it was necessary to the same time, and the colonists had not " Prob 0.000000000000000033819461323965
# Text: "The island, and it was necessary to the same time, and the colonists would ha" Prob 0.000000000000000018455703102703
# Text: "The island, and it was necessary to the same time, and the colonists would be" Prob 0.000000000000000012112847424061
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists had been " Prob 0.000000000000000034368457787794
# Text: "The island, and it was necessary to the same time, and the colonists would hav" Prob 0.000000000000000017881949123141
# Text: "The island, and it was necessary to the same time, and the colonists had not b" Prob 0.000000000000000008475816161546
# Text: "The island, and it was necessary to the same time, and the colonists would be " Prob 0.000000000000000008473037661869
# Text: "The island, and it was necessary to the same time, and the colonists had been
# " Prob 0.000000000000000005573993367226
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have" Prob 0.000000000000000017847182721995
# Text: "The island, and it was necessary to the same time, and the colonists had not be" Prob 0.000000000000000007948285861793
# Text: "The island, and it was necessary to the same time, and the colonists had been t" Prob 0.000000000000000003690091590088
# Text: "The island, and it was necessary to the same time, and the colonists had been s" Prob 0.000000000000000003686717106779
# Text: "The island, and it was necessary to the same time, and the colonists had been d" Prob 0.000000000000000003163452991036
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have " Prob 0.000000000000000016167314555520
# Text: "The island, and it was necessary to the same time, and the colonists had not bee" Prob 0.000000000000000006007252787698
# Text: "The island, and it was necessary to the same time, and the colonists had been de" Prob 0.000000000000000001692505108090
# Text: "The island, and it was necessary to the same time, and the colonists had been se" Prob 0.000000000000000001615831979354
# Text: "The island, and it was necessary to the same time, and the colonists would have
# " Prob 0.000000000000000001408642778051
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists had not been" Prob 0.000000000000000005964897004432
# Text: "The island, and it was necessary to the same time, and the colonists would have b" Prob 0.000000000000000005267960942409
# Text: "The island, and it was necessary to the same time, and the colonists would have n" Prob 0.000000000000000001203999535277
# Text: "The island, and it was necessary to the same time, and the colonists would have t" Prob 0.000000000000000001200363042509
# Text: "The island, and it was necessary to the same time, and the colonists would have a" Prob 0.000000000000000000959654621629
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists had not been " Prob 0.000000000000000005211311064568
# Text: "The island, and it was necessary to the same time, and the colonists would have be" Prob 0.000000000000000005046977987405
# Text: "The island, and it was necessary to the same time, and the colonists would have no" Prob 0.000000000000000000848096132835
# Text: "The island, and it was necessary to the same time, and the colonists had not been
# " Prob 0.000000000000000000675209904740
# Text: "The island, and it was necessary to the same time, and the colonists would have to" Prob 0.000000000000000000586982407015
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have bee" Prob 0.000000000000000004768707811897
# Text: "The island, and it was necessary to the same time, and the colonists would have not" Prob 0.000000000000000000626951102129
# Text: "The island, and it was necessary to the same time, and the colonists had not been t" Prob 0.000000000000000000573239369824
# Text: "The island, and it was necessary to the same time, and the colonists had not been s" Prob 0.000000000000000000566824584174
# Text: "The island, and it was necessary to the same time, and the colonists had not been c" Prob 0.000000000000000000544817650772
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been" Prob 0.000000000000000004746893404783
# Text: "The island, and it was necessary to the same time, and the colonists would have not " Prob 0.000000000000000000522828036464
# Text: "The island, and it was necessary to the same time, and the colonists had not been se" Prob 0.000000000000000000245892904616
# Text: "The island, and it was necessary to the same time, and the colonists had not been th" Prob 0.000000000000000000228613773704
# Text: "The island, and it was necessary to the same time, and the colonists had not been ca" Prob 0.000000000000000000217180121386
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been " Prob 0.000000000000000004114897638290
# Text: "The island, and it was necessary to the same time, and the colonists would have been
# " Prob 0.000000000000000000585776170887
# Text: "The island, and it was necessary to the same time, and the colonists had not been thr" Prob 0.000000000000000000115022411006
# Text: "The island, and it was necessary to the same time, and the colonists had not been see" Prob 0.000000000000000000089798074602
# Text: "The island, and it was necessary to the same time, and the colonists had not been car" Prob 0.000000000000000000088022951469
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been s" Prob 0.000000000000000000479618034120
# Text: "The island, and it was necessary to the same time, and the colonists would have been t" Prob 0.000000000000000000460233211561
# Text: "The island, and it was necessary to the same time, and the colonists would have been a" Prob 0.000000000000000000379857984294
# Text: "The island, and it was necessary to the same time, and the colonists would have been d" Prob 0.000000000000000000344788705797
# Text: "The island, and it was necessary to the same time, and the colonists would have been c" Prob 0.000000000000000000330845465049
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been se" Prob 0.000000000000000000210789233500
# Text: "The island, and it was necessary to the same time, and the colonists would have been de" Prob 0.000000000000000000160005643015
# Text: "The island, and it was necessary to the same time, and the colonists would have been th" Prob 0.000000000000000000157859923581
# Text: "The island, and it was necessary to the same time, and the colonists would have been ca" Prob 0.000000000000000000140994899964
# Text: "The island, and it was necessary to the same time, and the colonists would have been tr" Prob 0.000000000000000000112882003623
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been thr" Prob 0.000000000000000000084927764402
# Text: "The island, and it was necessary to the same time, and the colonists would have been see" Prob 0.000000000000000000082929257268
# Text: "The island, and it was necessary to the same time, and the colonists would have been dec" Prob 0.000000000000000000057959873437
# Text: "The island, and it was necessary to the same time, and the colonists would have been tra" Prob 0.000000000000000000057159033357
# Text: "The island, and it was necessary to the same time, and the colonists would have been car" Prob 0.000000000000000000056670098530
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been thro" Prob 0.000000000000000000079008679658
# Text: "The island, and it was necessary to the same time, and the colonists would have been seen" Prob 0.000000000000000000067040752675
# Text: "The island, and it was necessary to the same time, and the colonists would have been carr" Prob 0.000000000000000000040540092741
# Text: "The island, and it was necessary to the same time, and the colonists would have been deci" Prob 0.000000000000000000037611259449
# Text: "The island, and it was necessary to the same time, and the colonists would have been trac" Prob 0.000000000000000000029238165704
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been throw" Prob 0.000000000000000000059703731727
# Text: "The island, and it was necessary to the same time, and the colonists would have been carri" Prob 0.000000000000000000037656634829
# Text: "The island, and it was necessary to the same time, and the colonists would have been decid" Prob 0.000000000000000000034817708962
# Text: "The island, and it was necessary to the same time, and the colonists would have been seen " Prob 0.000000000000000000027039766820
# Text: "The island, and it was necessary to the same time, and the colonists would have been trace" Prob 0.000000000000000000026185576822
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been thrown" Prob 0.000000000000000000054933154953
# Text: "The island, and it was necessary to the same time, and the colonists would have been carrie" Prob 0.000000000000000000037158329596
# Text: "The island, and it was necessary to the same time, and the colonists would have been decide" Prob 0.000000000000000000034787154978
# Text: "The island, and it was necessary to the same time, and the colonists would have been traces" Prob 0.000000000000000000014381452603
# Text: "The island, and it was necessary to the same time, and the colonists would have been traced" Prob 0.000000000000000000007226865370
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been thrown " Prob 0.000000000000000000049254259548
# Text: "The island, and it was necessary to the same time, and the colonists would have been carried" Prob 0.000000000000000000036856554075
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided" Prob 0.000000000000000000034750933514
# Text: "The island, and it was necessary to the same time, and the colonists would have been traces " Prob 0.000000000000000000010289693843
# Text: "The island, and it was necessary to the same time, and the colonists would have been traced " Prob 0.000000000000000000005478759298
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been carried " Prob 0.000000000000000000028263662932
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided " Prob 0.000000000000000000025212216270
# Text: "The island, and it was necessary to the same time, and the colonists would have been thrown o" Prob 0.000000000000000000011212152091
# Text: "The island, and it was necessary to the same time, and the colonists would have been thrown u" Prob 0.000000000000000000007235507953
# Text: "The island, and it was necessary to the same time, and the colonists would have been traces o" Prob 0.000000000000000000006548332910
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided t" Prob 0.000000000000000000012808104187
# Text: "The island, and it was necessary to the same time, and the colonists would have been carried t" Prob 0.000000000000000000012548641701
# Text: "The island, and it was necessary to the same time, and the colonists would have been thrown on" Prob 0.000000000000000000007015204876
# Text: "The island, and it was necessary to the same time, and the colonists would have been traces of" Prob 0.000000000000000000006346233461
# Text: "The island, and it was necessary to the same time, and the colonists would have been thrown up" Prob 0.000000000000000000005311102147
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided th" Prob 0.000000000000000000010679768471
# Text: "The island, and it was necessary to the same time, and the colonists would have been carried to" Prob 0.000000000000000000009670698596
# Text: "The island, and it was necessary to the same time, and the colonists would have been thrown on " Prob 0.000000000000000000005374873410
# Text: "The island, and it was necessary to the same time, and the colonists would have been traces of " Prob 0.000000000000000000005236139307
# Text: "The island, and it was necessary to the same time, and the colonists would have been thrown up " Prob 0.000000000000000000003297311154
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided tha" Prob 0.000000000000000000008570457909
# ...
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the col" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the sai" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the set" Prob 0.000000000000000000000000000000
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engi" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the sail" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the sett" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the cold" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the colo" Prob 0.000000000000000000000000000000
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engin" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the sailo" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the settl" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the colon" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the cold " Prob 0.000000000000000000000000000000
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engine" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the sailor" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the settle" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the coloni" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the cold w" Prob 0.000000000000000000000000000000
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the enginee" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the settler" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the sailor " Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the colonis" Prob 0.000000000000000000000000000000
# Text: "The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the sailor," Prob 0.000000000000000000000000000000
#
#
# Beam 0 information:
# The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the enginee
# tensor(0., device='mps:0', grad_fn=<ExpBackward0>)
# Beam 1 information:
# The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the settler
# tensor(0., device='mps:0', grad_fn=<ExpBackward0>)
# Beam 2 information:
# The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the sailor
# tensor(0., device='mps:0', grad_fn=<ExpBackward0>)
# Beam 3 information:
# The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the colonis
# tensor(0., device='mps:0', grad_fn=<ExpBackward0>)
# Beam 4 information:
# The island, and it was necessary to the same time, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the engineer, “we will make a few minutes, and it was necessary to the same time, and it was necessary to the colonists had not been thrown on the shore, and the colonists would have been decided that the sailor,
# tensor(0., device='mps:0', grad_fn=<ExpBackward0>)
